# %%
import pandas as pd

# %%
df = pd.read_csv("../data/sample_data.csv")

print("Datos cargados:")
print(df.head())
# Out:
# 📂 Datos cargados:
#   origen destino  tiempo
# 0      A       B      10
# 1      B       C      15
# 2      A       C      20
# 3      C       A      25
